# %%
# Import libraries
import pandas as pd
from mlxtend.frequent_patterns import apriori ,association_rules
import matplotlib.pyplot as plt
import seaborn as snsno

# %%
#  Load data from an Excel file named "Basket_Cosmetic.xlsx"
df_sale_product=pd.read_excel("Basket_Cosmetic.xlsx")

# %%
#Check the shape (number of rows and columns) of the dataset
df_sale_product.shape
# Out:
# (4792, 10)

# %%
# Get information about the dataset, including data types and non-null counts
df_sale_product.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4792 entries, 0 to 4791
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   OrderId                4792 non-null   int64
#  1   OrderQty               4792 non-null   int64
#  2   SaleAmount             4792 non-null   float64
#  3   CountOrder             4792 non-null   int64
#  4   AttributeSetName       4792 non-null   object
#  5   AttributeSetId         4792 non-null   int64
#  6   CategoryName_Level2    4792 non-null   object
#  7   ProductMiddleCategory  4792 non-null   object
#  8   ProductName            4792 non-null   object
#  9   ProductCode            4792 non-null   int64
# dtypes: float64(1), int64(5), object(4)
# memory usage: 374.5+ KB

# %%
# display the first two rows and the last row of the data to get an overview.
df_sale_product.head(2)
df_sale_product.tail(2)
# Out:
#       OrderId  OrderQty  SaleAmount  CountOrder  AttributeSetName  \
# 4790   365641         1    280000.0           1  آرايشي و بهداشتي
# 4791   358833         1    168000.0           1  آرايشي و بهداشتي
#
#       AttributeSetId CategoryName_Level2 ProductMiddleCategory  ProductName  \
# 4790              17        لوازم آرایشی      آرايشي و بهداشتي  highlighter
# 4791              17        لوازم آرایشی      آرايشي و بهداشتي  highlighter
#
#       ProductCode
# 4790       357021
# 4791       357021

# %%
# Generate descriptive statistics for the dataset, including count, mean, min, max, etc.
df_sale_product.describe(include = 'all')
# Out:
#               OrderId     OrderQty    SaleAmount   CountOrder  \
# count     4792.000000  4792.000000  4.792000e+03  4792.000000
# unique            NaN          NaN           NaN          NaN
# top               NaN          NaN           NaN          NaN
# freq              NaN          NaN           NaN          NaN
# mean    366736.435309     1.137312  1.468123e+05     1.000835
# std       8837.134977     0.735771  2.106541e+05     0.028883
# min     352685.000000     0.000000  0.000000e+00     1.000000
# 25%     358701.000000     1.000000  4.400000e+04     1.000000
# 50%     366208.000000     1.000000  8.900000e+04     1.000000
# 75%     374290.000000     1.000000  1.780000e+05     1.000000
# max     382026.000000    19.000000  3.737600e+06     2.000000
#
#         AttributeSetName  AttributeSetId CategoryName_Level2  \
# count               4792          4792.0                4792
# unique                 1             NaN                   6
# top     آرايشي و بهداشتي             NaN        لوازم آرایشی
# freq                4792             NaN                1985
# mean                 NaN            17.0                 NaN
# std                  NaN             0.0                 NaN
# min                  NaN            17.0                 NaN
# 25%                  NaN            17.0                 NaN
# 50%                  NaN            17.0                 NaN
# 75%                  NaN            17.0                 NaN
# max                  NaN            17.0                 NaN
#
#        ProductMiddleCategory ProductName    ProductCode
# count                   4792        4792    4792.000000
# unique                     3          32            NaN
# top         آرايشي و بهداشتي     perfume            NaN
# freq                    4699         750            NaN
# mean                     NaN         NaN  474233.797579
# std                      NaN         NaN   91167.328871
# min                      NaN         NaN  253867.000000
# 25%                      NaN         NaN  473203.000000
# 50%                      NaN         NaN  501795.000000
# 75%                      NaN         NaN  540831.000000
# max                      NaN         NaN  543073.000000

# %%
# Insert a new column named 'quantity' with a default value of 1 at position 9
df_sale_product.insert(9, 'quantity',1)

# %%
# Group and pivot the data to create a basket of products by OrderId
product_basket = (df_sale_product.groupby(['OrderId', 'ProductName'])['quantity']).sum().unstack().reset_index().fillna(0).set_index('OrderId')

# %%
# Define a function to convert values to 0 if they are less than or equal to 0, and 1 if greater than or equal to 1
def convto0(x):
    if (x<=0):
        return 0
    if (x>=1):
        return 1
# Apply the conversion function to the product_basket dataset
Basket_sets = product_basket.applymap(convto0)
Basket_sets.head()
# Out:
# ProductName  Gel creame  Mascara  Rough skin  Sunscreen  Toner   \
# OrderId
# 352685                0        0           0          0       0
# 352697                0        0           0          0       0
# 352740                0        0           0          1       0
# 352743                0        0           0          0       0
# 352761                1        1           0          0       0
#
# ProductName  Women's mom stick  body lotion  body shampoo  body splash  \
# OrderId
# 352685                       0            0             0            0
# 352697                       0            0             0            0
# 352740                       0            0             0            0
# 352743                       0            0             0            0
# 352761                       0            0             0            0
#
# ProductName  coclear stick  ...  moisturizing lotion  nail polish  perfume  \
# OrderId                     ...
# 352685                   0  ...                    0            1        1
# 352697                   0  ...                    0            0        0
# 352740                   0  ...                    0            0        0
# 352743                   0  ...                    0            0        0
# 352761                   1  ...                    0            0        0
#
# ProductName  shampoo  skin cream  skin foam  skin primer  soap  soft cream  \
# OrderId
# 352685             0           0          0            0     0           0
# 352697             1           0          0            0     0           0
# 352740             1           0          0            0     0           0
# 352743             1           0          0            0     0           1
# 352761             0           0          0            0     0           0
#
# ProductName  spray
# OrderId
# 352685           0
# 352697           0
# 352740           0
# 352743           0
# 352761           0
#
# [5 rows x 32 columns]

# %%
# Use the Apriori algorithm to mine frequent itemsets from the basket dataset
frequent_itemsets = apriori(Basket_sets.astype('bool'), min_support = 0.0008, use_colnames = True)
frequent_itemsets['length'] = frequent_itemsets['itemsets'].apply(lambda x: len(x))
frequent_itemsets
# Out:
#       support                                           itemsets  length
# 0    0.058560                                       (Gel creame)       1
# 1    0.059374                                          (Mascara)       1
# 2    0.010167                                       (Rough skin)       1
# 3    0.103294                                        (Sunscreen)       1
# 4    0.017893                                           (Toner )       1
# ..        ...                                                ...     ...
# 702  0.000813  (eye shadow, nail polish, eye liner, perfume, ...       5
# 703  0.000813  (micellar water, nail polish, eye liner, perfu...       5
# 704  0.000813  (micellar water, eye shadow, nail polish, eye ...       5
# 705  0.000813  (micellar water, eye shadow, nail polish, perf...       5
# 706  0.000813  (micellar water, eye shadow, nail polish, eye ...       6
#
# [707 rows x 3 columns]

# %%
# Filter the itemsets where the length is greater than or equal to 1
lenght=frequent_itemsets['itemsets'].str.len()
Filter1=lenght>=1
frequent_itemsets[Filter1]
# Out:
#       support                                           itemsets  length
# 0    0.058560                                       (Gel creame)       1
# 1    0.059374                                          (Mascara)       1
# 2    0.010167                                       (Rough skin)       1
# 3    0.103294                                        (Sunscreen)       1
# 4    0.017893                                           (Toner )       1
# ..        ...                                                ...     ...
# 702  0.000813  (eye shadow, nail polish, eye liner, perfume, ...       5
# 703  0.000813  (micellar water, nail polish, eye liner, perfu...       5
# 704  0.000813  (micellar water, eye shadow, nail polish, eye ...       5
# 705  0.000813  (micellar water, eye shadow, nail polish, perf...       5
# 706  0.000813  (micellar water, eye shadow, nail polish, eye ...       6
#
# [707 rows x 3 columns]

# %%
# Generate association rules from the frequent itemsets based on support
association_rules_data = association_rules(frequent_itemsets, metric = 'support', min_threshold = 0.0008)
association_rules_data
# Out:
#         antecedents                                        consequents  \
# 0      (Gel creame)                                          (Mascara)
# 1         (Mascara)                                       (Gel creame)
# 2       (Sunscreen)                                       (Gel creame)
# 3      (Gel creame)                                        (Sunscreen)
# 4      (Gel creame)                                (Women's mom stick)
# ...             ...                                                ...
# 3365   (eye shadow)  (micellar water, nail polish, eye liner, perfu...
# 3366  (nail polish)  (micellar water, eye shadow, eye liner, perfum...
# 3367    (eye liner)  (micellar water, eye shadow, nail polish, perf...
# 3368      (perfume)  (micellar water, eye shadow, nail polish, eye ...
# 3369     (eye lner)  (micellar water, eye shadow, nail polish, eye ...
#
#       antecedent support  consequent support   support  confidence       lift  \
# 0               0.058560            0.059374  0.002033    0.034722   0.584808
# 1               0.059374            0.058560  0.002033    0.034247   0.584808
# 2               0.103294            0.058560  0.006507    0.062992   1.075678
# 3               0.058560            0.103294  0.006507    0.111111   1.075678
# 4               0.058560            0.013827  0.001220    0.020833   1.506740
# ...                  ...                 ...       ...         ...        ...
# 3365            0.042294            0.000813  0.000813    0.019231  23.644231
# 3366            0.071980            0.000813  0.000813    0.011299  13.892655
# 3367            0.028467            0.000813  0.000813    0.028571  35.128571
# 3368            0.228955            0.000813  0.000813    0.003552   4.367673
# 3369            0.034974            0.000813  0.000813    0.023256  28.593023
#
#       leverage  conviction
# 0    -0.001444    0.974462
# 1    -0.001444    0.974824
# 2     0.000458    1.004730
# 3     0.000458    1.008794
# 4     0.000410    1.007156
# ...        ...         ...
# 3365  0.000779    1.018779
# 3366  0.000755    1.010606
# 3367  0.000790    1.028575
# 3368  0.000627    1.002749
# 3369  0.000785    1.022977
#
# [3370 rows x 9 columns]

# %%
association_rules_data.dtypes
# Out:
# antecedents            object
# consequents            object
# antecedent support    float64
# consequent support    float64
# support               float64
# confidence            float64
# lift                  float64
# leverage              float64
# conviction            float64
# dtype: object

# %%
# Export the rules to an Excel file named 'BasketAnalysisOutput.xlsx'
excell=association_rules_data.to_excel('BasketAnalysisOutput.xlsx')
